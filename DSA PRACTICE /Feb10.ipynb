# %%
# is prime_ or not 

x = int(input("enter the given number"))

if x <=1 :
    print(str(x) + "is not a prime number")
    
else:
    for i in range(2, x//2+1):
        if x% i == 0:
            print( str(x) +  " is not a prime number")
            break
    else:
        print( str(x) + " is a prime number")
# Out:
# 20 is not a prime number

# %%
s = "How can I "


print(len(s))
x = ~len(s)
print(x)
print(s[x:x+4])
print(s[-len(s):-(len(s)-3)])
# Out:
# 10
# -11
# How
# How

# %%
# Count the primes 

nu
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 # Count the primes
# ----> 3 nu
#
# NameError: name 'nu' is not defined

# %%
# Erasthenes algorithm 
n=int(input("enter a number"))

for i in range(2, int(n^2)+1):
    for j in range(i*i, n,i):

# %% [markdown]
# ================================================
# # **FEB 11**

# %%
# Patterns 
# 1. square pattern. 

def squarePattern(n):
    for i in range(n):
        for j in range(n):
                if i >=j:
                    print("*", end = " ")
        print()

squarePattern(4)
# Out:
# *
# * *
# * * *
# * * * *

# %%
n = 4
for i in range(1, n+1):
    for j in range(i):
        print("*", end = " ")
    print()
# Out:
# *
# * *
# * * *
# * * * *

# %% [markdown]
# ===================
# # **Feb12**

# %%
n = int(input(" Enter n "))
for i in range(n):
    for j in range(n,0,-1):
        for k in range(n-i):
            print(j, end = "")

    print("$")
# Out:
# 4444333322221111$
# 444333222111$
# 44332211$
# 4321$

# %%
n = int(input(" Enter n "))
for i in range(n):
    for j in range(n,0,-1):
        print (f"{j}"* (n-i),end = "")

    print("$")
# Out:
# 4 4 4 4 3 3 3 3 2 2 2 2 1 1 1 1 $
# 4 4 4 3 3 3 2 2 2 1 1 1 $
# 4 4 3 3 2 2 1 1 $
# 4 3 2 1 $

# %% [markdown]
# # **BIT MANIPULATION**

# %% [markdown]
# - A bit is a part of the number or digit of the number. It will be either 0 or 1.
#
# Hardware    ---> ON (1)          | Off(0)
# Electricity ---> High Voltage(1) | Low Voltage (0)
# Logic/programs -> True (1)       | False(0)
#
# Bit Manipulation: Using bits manage the data
#
# 1. Number Systems: Are the numerical values which is used in industries to build any product.
#
# **Types of Number Systems:**
#    - 1. Decimal Numbers    Base : 10       Range: 0-9          Example:245    prefix: Nothing
#    - 2. Binary Numbers     Base : 2        Range: 0,1          Example: 1010  prefix: 0b
#    - 3. Octal Numbers      Base : 8        Range: 0-7          Example: Oct(123) prefix: 0o
#    - 4. Hexa Decimal       Base : 16       Range: 0-9+, A = 10; B = 11; C = 12; D = 13; E = 14; F =  15    Example:  HEX(AF) prefix : ox
#
#    **Number Conversion:**
#    1. dec -> bin, oct, hex
#    2. bin -> dec, oct, hex
#    3. oct -> dec, bin
#    4. hex -> dec, bin
#
#   -  int to dec -- 253
#   -  dec to bin -- 10 /2    divide by 2 till 0 , right values from bottom to top 1010
#   -  bin to dec --  right to left   1 * 2 power 3 + 0 * 2 power 2 + 1 * 2 power 1 + 0 * 2  power 0 . =10
#   - dec to Octa -- 10 /8-- divide by 8 -- oCT (12)
#   - octa to dec --  1*8 power 1 + 2 * 8 power 0  =. 10
#   - dec to hexa -- 23 -- 23/ 12 -- hex(17)
#   - hexa to dec --  1 * 16 power 1 + 7 * 16 power 0  = 23
#   - bin to oct  -- 101111 === divide by 3 101. 111, if there are not 3 add 0 to left
#   - bin to hexa -- 11011101 --.divide into 2 parts by 4, hex(1DD)
#   - hexa to bin -- 1* 16 power 2 + 13* 16 power 1 + 13* 16 power 2
#
#   # Convert the following :
#   1. 123 --> bin, Octal, hexa ---
#    ANS : 123 --> BIn Ans:  1111011 bn
#         123--> Octa ans:  OCT(173)
#         123 --> hexa ans : HEX (7B)
#   2. 1011011011 ----> dec, octa, hexa
#         dec answer : 731
#         octa answer: OCT(1333)
#         hexa : HEXA 3DD
#   3. oct(678) ---> dec, bin, hexa
#         dec : Not a valid
#         bin: Not a valid
#         hex: Not a valid
#   4. hex(1DD1F)--> dec, bin, hex
#     Dec --> 122143
#     Bin  --> 111011101000111111
#     hex: 1DD1F

# %% [markdown]
# n

# %%
n = oct(678)
b = bin(n)
print (b)

dec1 = int(b,2)
print (dec1)

oc = oct(n)
print(oc)
dec2 = int(oc,8)
print ( dec2)

h = hex(n)
print(h)
dec3 = int(h,16)
print(dec3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[99], line 2
#       1 n = oct(678)
# ----> 2 b = bin(n)
#       3 print (b)
#       5 dec1 = int(b,2)
#
# TypeError: 'str' object cannot be interpreted as an integer

# %% [markdown]
# # **BITWISE Operators and Their Operations
# # **ARRAYS**
#
# 1. **Bitwise Operators:**
#     - AND
#     - OR
#     - XOR
#     - Left Shift
#     - Right Shift
#
# 1. AND Operator (&):
#     Definition: If the both symbols are True , then only it is true otherwise false.
#
# 2. OR Operator (|):
#     Definition:  If either of the symbols is true, then it is true.
#
# 3. XOR Operator (^) :
#     Definition: If the bits are opposite then the add 1. other wise 0.
#
# 4. NOT Operator (~) :
#     Definition:
#     steps: 1. Find the bits of the number.
#             2. Make it 8 digit binary number then flip the bits and make sure to add zeros to left to make it 8
#             3. check the left most bit if it is 1, then  add'-'
#             4. Now convert the bits back to original
#             5. Two's Compiment: adding 1 at right most bit
#
# 5. left shift operator (<<):
#     Definition:
#         5<<2 : ans : 20
#
#         20>>2: ans: 5
#
# 6. Right Shift Operator(>>):

# %%
# bit wise operators 
print(10&5)
print(10|5)
print(10^5)
print(~5)
print(5<<2)
print(20>>2)
print(5<<4)
print(5>>4)
# Out:
# 0
# 15
# 15
# -6
# 20
# 5
# 80
# 0

# %% [markdown]
# ================================================================================================================
#
# # **FEB 14-ARRAYS**

# %% [markdown]
# # Array
# - Array : an array is an data structure types which is used to store multiple elements in a same container or at same memory location with different indexing locations.
#
# - lists : It is a dynamic array we can store [ int, str, list, obj,variables, dictionary ]
#         list is slower than dynamic array.
#
# Arrays VS Lists:
#
# - Arrays :
#
# Pros:
# 1. fast
#
# Cons :
# 1. Static
# 2. allows a single data type elements only
# 3. only forward indexing
# 4. leads to memory fragmentation if it is not used once it got created.
#
#
# Lists:
# Pros:
# 1. dynamic
# 2. Heterogenous [ it stores any data types]
# 3. It allows both forward indexing and backward indexing.
# 4. Compared to arrays it is slower.
# 5. It unlocks various functionalities and features.
#
#
#
# Common operation in lists and Arrays :
# - Creation
# - Addition
# - deletion
# - traversal
# - Searching
# - accessing
# - Updating

# %%
# Arrays. --> List 
# 1. Creation 
# How to create empty lists 
l1 = [1,2,3,4]
l2 = list()
# Inserting values into lists 
'''2. Insertion
We use two functions 
1. append --> Used to add the values at the end of the list append takes single argument
'''
l1.append(10) # Only 1 parameter given and is required 
print(l1)
'''
2. Insert --> Used to add the value at specific position and insert takes 2 parameters. 
'''
l1.insert(0,20 ) # Two parameters are given and is required
print(l1)

print(type(l1))

""" 2. Deletion : 
1. Remove: it is used to remove the element from the list by using element value . 
- remove function does not return anything 
2. Pop(): It is used to remove the element from the list by using index value. 
Both functions takes only single parameter
- If you dont pass any parameter for the pop function then by default it deletes the last element. 
- pop return the deleted value 
3. del keyword 
4. clear(): Used to clear the entire list elements and leave the empty list
"""

# I want to remove 10 from the list.
l1.remove(10)
print(l1)

# Pop
print(" Deleted value is " , l1.pop(0))
print("deleted element from list is:", val )
print(l1)

# 3. del used to delete through indexing
del l1[3]
print(l1)

# 4. Accessing 
print("oth index value is :", l1[0])
print("2nd index calue is :", l1[2])

# 5. Searching 
print( 4 in l1 )
print (100 in l1 )

# Updation: 
l1[0] = 10
print("oth index updated")
print(l1)

# Slicing 
print(l1[:])
print(l1[::])
print(l1[:len(l1)//2+1])
print(l1[::-1])

l1[-2:-(len(l1)+1):-1]
# Out:
# [1, 2, 3, 4, 10]
# [20, 1, 2, 3, 4, 10]
# <class 'list'>
# [20, 1, 2, 3, 4]
#  Deleted value is  20
# deleted element from list is: 4
# [1, 2, 3, 4]
# [1, 2, 3]
# oth index value is : 1
# 2nd index calue is : 3
# False
# False
# oth index updated
# [10, 2, 3]
# [10, 2, 3]
# [10, 2, 3]
# [10, 2]
# [3, 2, 10]
# [2, 10]

# %%
# Brute Force: 
# q : Find the duplicate in the list print true if duplicate found else false.

arr = [1,2,3,4,1]
print(type(arr))
def fun(arr):
    for i in range(len(arr)):
        for j in range(i+1, len(arr)):
         if arr[i] == arr[j]:
            return "Dupicate found in the array"
            break   
    return "Duplicate not found in the array"
print(fun(arr))
# Out:
# <class 'list'>
# Dupicate found in the array

# %%
arr = [1,2,7,8]
'''
Problem: find the two indices in the list 
 '''
# Return indices in list format 
for i in range(len(arr)): # i =0,1,2,3,4
    for j in range(n): 
        for j in range(i+1, n):
# Out:
# ' '

# %% [markdown]
# # **List**

# %% [markdown]
# # Creating a list with elelments
#
# l =[1,2,3,"hi","bye"]

# %%
l = [10,20,30]
l.insert(1,25)
print(l)
# Out:
# [10, 25, 20, 30]

# %%
# 1. Two Sum 

l =[]
n = int(input("enter the size of the array"))
for i in range(n):
    l.append(int(input()))
print(l)-
# Out:
# [1, 2, 2, 2, 2]

# %%
# take two helping inputs to keep track on mac profit and min stock 
class solution: 
    def maxProfit(self, prices: List[int]) -> int:

        min_stock = prices[0]
        max_profit = 0
        n = len(prices)

        for i in range(1,n):
            if min_stock>i:
                min_stock = i
            else:
                if prices[i]-min_stock > max_profi:
                    max_profit = prices[i] -min_stock
            print(max_profit)
        return max_profit

# %% [markdown]
# # **STRINGS**

# %%
num = 12321
temp = num
rev = 0

while temp > 0:
    digit = temp% 10
    rev = rev * 10 + digit
    temp = temp // 10
print(num == rev)
# Out:
# True
