# %% [markdown]
# # TUPLE

# %%
t = () # Tuple will start with () 
type(t)
# Out:
# tuple

# %%
t1 = (10,20,30)
t1
# Out:
# (10, 20, 30)

# %%
t1.count(10)
# Out:
# 1

# %%
t1.index(10)
# Out:
# 0

# %%
t1
# Out:
# (10, 20, 30)

# %%
t1[0]
# Out:
# 10

# %%
t1[0] = 100 # Immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 t1[0] = 100 # Immutable
#
# TypeError: 'tuple' object does not support item assignment

# %%
t1.append(40)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 t1.append(40)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
t1.remove(40)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 t1.remove(40)
#
# AttributeError: 'tuple' object has no attribute 'remove'

# %%
t1[1] = 200
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 t1[1] = 200
#
# TypeError: 'tuple' object does not support item assignment

# %%
t2 = (10,10,20)

# %%
t2
# Out:
# (10, 10, 20)

# %%
t2[:]
# Out:
# (10, 10, 20)

# %%
t2.sort()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 t2.sort()
#
# AttributeError: 'tuple' object has no attribute 'sort'

# %%
a = sorted(t2)# Output will be in list form 
type(a)
print(a)
# Out:
# [10, 10, 20]
