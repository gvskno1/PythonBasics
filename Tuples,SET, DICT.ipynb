# %% [markdown]
# # Tuples
# 1. Tuple is similar to List except that the objects in are immutable which means we cannot change the elements of a tuple once assigned.
# 2. When we do not want to change the data over time, tuple is a preferred data type.
# 3. Iterating over the elements of a tuple is faster compared to iterating over a list.
#
# # Tuple Creation.

# %%
tup1 = () # Empty tuple 
tup2 = (10,30,60) # tuple of integers numbers
tup3 = (10.77, 30.66, 60.89) # tuple of float numbers 
tup4 = ('one', 'two', "three") # tuple of strings 
tup5 = ('Asif', 25, (50,100), (150,90)) # Nested tuples 
tup6 = (100, 'Asif',17.765) # Tuple of mixed data types 
tup7 = ('Asif', 25, [50,100],[150,90], {'John', 'David'}, (99,22,33))

# %%
len(tup7) # length of list
# Out:
# 6

# %% [markdown]
# # Tuple Indexing

# %%
tup2[0] # Retrieve first element of the tuple
# Out:
# 10

# %%
tup4[0] # Retrieve first element of the tuple
# Out:
# 'one'

# %%
tup4[0][0] # Nested indexing - Access the first character of the first tuple element
# Out:
# 'o'

# %%
tup4[-1] # Last item of the tuple
# Out:
# 'three'

# %%
tup5[-1] # Last item of the tuple
# Out:
# (150, 90)

# %% [markdown]
# # Tuple Slicing

# %%
mytuple = ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')
mytuple[0:3] # Return all items from 0th to 3rd index location excluding 3 index item.
# Out:
# ('one', 'two', 'three')

# %%
mytuple[2:5] # List all items from 2nd to 5th index location excluding the last item
# Out:
# ('three', 'four', 'five')

# %%
mytuple[:3] # Return first three items
# Out:
# ('one', 'two', 'three')

# %%
mytuple[:2] # Return first two items
# Out:
# ('one', 'two')

# %%
mytuple[-3:] # Return last three items
# Out:
# ('six', 'seven', 'eight')

# %%
mytuple[-2:]
# Out:
# ('seven', 'eight')

# %%
mytuple[-1] # Return last item of the tuple
# Out:
# 'eight'

# %%
mytuple[:] # Return whole tuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %% [markdown]
# # Remove & Change Items

# %%
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
del mytuple[0] # Tuples are immutable which means we can't Delete tuple items
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 del mytuple[0] # Tuples are immutable which means we can't Delete tuple items
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
mytuple[0] = 1 # Tuples are immutable which means we can't change tuple items
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 mytuple[0] = 1 # Tuples are immutable which means we can't change tuple items
#
# TypeError: 'tuple' object does not support item assignment

# %%
del mytuple # Deleting entire tuple object is possible.

# %%
mytuple
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 mytuple
#
# NameError: name 'mytuple' is not defined

# %% [markdown]
# # Loop through a tuple

# %%
mytuple = ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
for  i in mytuple:
    print (i)
# Out:
# one
# two
# three
# four
# five
# six
# seven
# eight

# %%
for i in enumerate(mytuple):
    print(i)
# Out:
# (0, 'one')
# (1, 'two')
# (2, 'three')
# (3, 'four')
# (4, 'five')
# (5, 'six')
# (6, 'seven')
# (7, 'eight')

# %%
mytuple1 = ('one', 'two', 'three', 'four', 'one', 'one', 'two', 'three')
mytuple1.count('one') # Number of times item "one" occured in the tuple.
# Out:
# 3

# %%
mytuple1.count('two') # Occurence of item 'two' in the tuple
# Out:
# 2

# %%
mytuple1.count('four') # Occurence of item 'four' in the tuple
# Out:
# 1

# %% [markdown]
# # Tuple Membership

# %%
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
'one' in mytuple # check if 'one' exist in the list
# Out:
# True

# %%
'ten' in mytuple # Check if 'ten' exist in the list
# Out:
# False

# %%
if 'three' in mytuple: # Check if 'three' exist in the list 
    print('Three is present in the tuple')
else:
    print('Three is not present in the tuple')
# Out:
# Three is present in the tuple

# %%
if 'eleven' in mytuple: # check if 'eleven' exist in the list 
    print('eleven is present in the tuple')
else:
    print('eleven is not present in the tuple')
# Out:
# eleven is not present in the tuple
