# %% [markdown]
# # **OpenCV & Image Processing**

# %%
# pip install opencv-python

# %%
import numpy as np 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread(r'/Users/venkatasaikumargundu/Desktop/elephant.jpg')

# %%
img
# Out:
# array([[[183, 182, 168],
#         [183, 182, 168],
#         [183, 182, 168],
#         ...,
#         [187, 185, 174],
#         [188, 186, 175],
#         [188, 186, 175]],
#
#        [[183, 182, 168],
#         [183, 182, 168],
#         [183, 182, 168],
#         ...,
#         [188, 186, 175],
#         [188, 186, 175],
#         [188, 186, 175]],
#
#        [[183, 182, 168],
#         [183, 182, 168],
#         [182, 181, 167],
#         ...,
#         [188, 186, 175],
#         [188, 186, 175],
#         [188, 186, 175]],
#
#        ...,
#
#        [[103, 177, 181],
#         [ 96, 174, 173],
#         [ 95, 177, 172],
#         ...,
#         [ 85, 163, 156],
#         [ 87, 165, 158],
#         [ 74, 152, 145]],
#
#        [[104, 178, 182],
#         [ 96, 174, 173],
#         [ 98, 180, 175],
#         ...,
#         [ 74, 154, 147],
#         [ 74, 157, 149],
#         [ 70, 153, 145]],
#
#        [[104, 178, 182],
#         [ 95, 173, 172],
#         [ 96, 179, 171],
# ...

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (360, 540, 3)

# %%
plt.imshow(img)

# %%
# IN matplotlib we see --> R G B 
# BUt in openCV channel --- B G R

# %%
img
# Out:
# array([[[183, 182, 168],
#         [183, 182, 168],
#         [183, 182, 168],
#         ...,
#         [187, 185, 174],
#         [188, 186, 175],
#         [188, 186, 175]],
#
#        [[183, 182, 168],
#         [183, 182, 168],
#         [183, 182, 168],
#         ...,
#         [188, 186, 175],
#         [188, 186, 175],
#         [188, 186, 175]],
#
#        [[183, 182, 168],
#         [183, 182, 168],
#         [182, 181, 167],
#         ...,
#         [188, 186, 175],
#         [188, 186, 175],
#         [188, 186, 175]],
#
#        ...,
#
#        [[103, 177, 181],
#         [ 96, 174, 173],
#         [ 95, 177, 172],
#         ...,
#         [ 85, 163, 156],
#         [ 87, 165, 158],
#         [ 74, 152, 145]],
#
#        [[104, 178, 182],
#         [ 96, 174, 173],
#         [ 98, 180, 175],
#         ...,
#         [ 74, 154, 147],
#         [ 74, 157, 149],
#         [ 70, 153, 145]],
#
#        [[104, 178, 182],
#         [ 95, 173, 172],
#         [ 96, 179, 171],
# ...

# %%
fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
fix_img
# Out:
# array([[[168, 182, 183],
#         [168, 182, 183],
#         [168, 182, 183],
#         ...,
#         [174, 185, 187],
#         [175, 186, 188],
#         [175, 186, 188]],
#
#        [[168, 182, 183],
#         [168, 182, 183],
#         [168, 182, 183],
#         ...,
#         [175, 186, 188],
#         [175, 186, 188],
#         [175, 186, 188]],
#
#        [[168, 182, 183],
#         [168, 182, 183],
#         [167, 181, 182],
#         ...,
#         [175, 186, 188],
#         [175, 186, 188],
#         [175, 186, 188]],
#
#        ...,
#
#        [[181, 177, 103],
#         [173, 174,  96],
#         [172, 177,  95],
#         ...,
#         [156, 163,  85],
#         [158, 165,  87],
#         [145, 152,  74]],
#
#        [[182, 178, 104],
#         [173, 174,  96],
#         [175, 180,  98],
#         ...,
#         [147, 154,  74],
#         [149, 157,  74],
#         [145, 153,  70]],
#
#        [[182, 178, 104],
#         [172, 173,  95],
#         [171, 179,  96],
# ...

# %%
fix_img.shape
# Out:
# (360, 540, 3)

# %%
plt.imshow(fix_img)

# %%
img_gray = cv2.imread(r'/Users/venkatasaikumargundu/Desktop/elephant.jpg', cv2.IMREAD_GRAYSCALE)

# %%
img_gray
# Out:
# array([[178, 178, 178, ..., 182, 183, 183],
#        [178, 178, 178, ..., 183, 183, 183],
#        [178, 178, 177, ..., 183, 183, 183],
#        ...,
#        [170, 165, 166, ..., 152, 154, 141],
#        [171, 165, 169, ..., 143, 145, 141],
#        [171, 164, 167, ..., 137, 138, 144]], shape=(360, 540), dtype=uint8)

# %%
img_gray.shape
# Out:
# (360, 540)

# %%
img_gray.min()
# Out:
# np.uint8(0)

# %%
img_gray.max()
# Out:
# np.uint8(255)

# %%
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap ='gray')

# %%
plt.imshow(img_gray, cmap ='magma')

# %%
plt.imshow(img_gray, cmap ='Accent')

# %%
plt.imshow(img)

# %%
plt.imshow(fix_img)

# %%
fix_img.shape
# Out:
# (360, 540, 3)

# %%
fix_img_1 = cv2.resize(fix_img,(500, 367))

# %%
fix_img_1.shape
# Out:
# (367, 500, 3)

# %%
w_ratio = 0.5 
h_ratio = 0.5

# %%
fix_img_2 = cv2.resize(fix_img,(0,0), fix_img, w_ratio, h_ratio)

# %%
fix_img_2
# Out:
# array([[[168, 182, 183],
#         [168, 182, 183],
#         [167, 181, 182],
#         ...,
#         [176, 184, 187],
#         [175, 186, 188],
#         [175, 186, 188]],
#
#        [[168, 182, 183],
#         [167, 181, 182],
#         [167, 181, 182],
#         ...,
#         [177, 185, 188],
#         [175, 186, 188],
#         [176, 187, 189]],
#
#        [[167, 181, 182],
#         [167, 181, 182],
#         [166, 180, 181],
#         ...,
#         [178, 186, 189],
#         [177, 188, 190],
#         [177, 188, 190]],
#
#        ...,
#
#        [[178, 174,  99],
#         [157, 164,  80],
#         [149, 160,  74],
#         ...,
#         [157, 163,  83],
#         [162, 166,  92],
#         [153, 157,  83]],
#
#        [[177, 175,  99],
#         [161, 169,  85],
#         [146, 159,  72],
#         ...,
#         [142, 150,  68],
#         [150, 155,  79],
#         [153, 159,  82]],
#
#        [[177, 176, 100],
#         [166, 175,  91],
#         [148, 161,  75],
# ...

# %%
plt.imshow(fix_img_2)

# %%
img3 = cv2.flip(fix_img_2,1)

# %%
plt.imshow(img3)

# %%
cv2.imwrite('mew gen image.jpg',img3)
# Out:
# True

# %%
img4 = cv2.flip(fix_img_2,0)
plt.imshow(img4)

# %%
#=========================
