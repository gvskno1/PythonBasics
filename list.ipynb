# %% [markdown]
# # 1st program -- WORKING WITH NUMBER & OPERATOR (ARITHMETIC)

# %%
1
# Out:
# 1

# %%
2
# Out:
# 2

# %%
3
# Out:
# 3

# %%
1 + 2
# Out:
# 3

# %%
10 + 5
# Out:
# 15

# %%
10 - 5
# Out:
# 5

# %%
10 * 5
# Out:
# 50

# %%
10 / 5 #float division
# Out:
# 2.0

# %%
10 // 5 # int division
# Out:
# 2

# %%
3 * 2
# Out:
# 6

# %%
3 ** 2 # power
# Out:
# 9

# %%
10 / 5
# Out:
# 2.0

# %%
10 // 5
# Out:
# 2

# %%
10 % 5  #modulus
# Out:
# 0

# %%
10+5*(3//6) # BODMAS -- bracket, order, division, mult, add, sub
# Out:
# 10

# %%
10+5*3//6
# Out:
# 12

# %% [markdown]
# # 2nd Programe ( working with python variable) syntax -- (varaible name = value)

# %%
v = 8
v
# Out:
# 8

# %%
8 = v
# Out:
#   Cell In[18], line 1
#     8 = v
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
8a = 10
8a

# %%
a8 = 10
a8

# %%
# why python called as dynamic

a = 'nit'
type(a)

# %%
a$ = 34
a$

# %%
a_ = 35
a_

# %%
Nit = 56
nit

# %%
Nit

# %%
hello = 67
hello

# %%
import keyword
keyword.kwlist

# %%
else = 6

# %%
Def = 7
Def

# %%
len(keyword.kwlist)

# %% [markdown]
# #python variable declaration we learned
#
# - what is varible ?
# - otheer names variable == object = identifier
# - rules tod python variable
# - variable = value (syntax)
# - value also called datatypes

# %% [markdown]
# # 3rd code -- python datatypes

# %%
i = 34
I

# %%
i

# %%
type(i)

# %%
i1 = 9
i1

# %%
type(i1)

# %%
f = 110.34
f

# %%
type(f)

# %%
f1 = 1e0 
f1

# %%
type(f1)

# %%
f2 = 2e1
f2

# %%
type(f2)

# %%
f3 = 3.2e3
f3

# %%
f4 = 2.4E2
f4

# %%
f5 = 3g2
f5

# %%
f

# %%
id(f)

# %%
2 + 3

10 + 5

10 - 5

# %%
print(2 + 3)

print(10 + 5)

print(10 - 5)

# %%
import keyword
keyword.kwlist

# %%
b = true

# %%
b = True
b

# %%
b1 = False
b1

# %%
b2 = None # operator overloading in oops -- polymorphism 
b2

# %%
True + True

# %%
True + False

# %%
False * False

# %%
False / True # float division

# %%
False // True #int division

# %% [markdown]
# # 8th

# %%
c = 1 + 2j
c

# %%
c.real

# %%
c.imag

# %%
d = 5 + 6j
d

# %%
print(c)
print(d)

# %%
c + d

# %%
c - d

# %% [markdown]
# # string

# %%
s = welcome 
s

# %%
s = 'welcome' 
s

# %%
s1 = "welcome"
s1

# %%
s2 = '''welcome'''
s2

# %%
s3 = '''welcome to 
            nareshit
                fsds with 
                    genai & agenticai'''
s3

# %% [markdown]
# # python operator

# %%
x, y = 10, 5

# %%
x + y

# %%
x - y

# %%
x * y

# %%
x // y

# %%
x / y

# %%
x ** y

# %% [markdown]
# # ASSIGNMENT OPERATOR

# %% [markdown]
# x

# %%
x += 2

# %%
x

# %%
x += 2

# %%
x

# %%
x *= 2
x

# %%
x

# %%
x //= 2
x

# %%
x /= 2

# %%
x

# %% [markdown]
# # unary operator

# %%
n = 7 #negattion
n

# %%
m = -n
m

# %% [markdown]
# # Relational operator ( we are using this for comparing)

# %%
a = 5
b = 6

# %%
a < b

# %%
a > b

# %%
a == b

# %%
a != b

# %%
b = 5
b

# %%
a == b

# %%
a != b

# %%
print(a)
print(b)

# %%
b = 7

# %%
print(a)
print(b)

# %%
a >= b

# %%
a <= b

# %% [markdown]
# # logical operator

# %%
a = 5
b = 4

# %%
a < 8 and b < 5

# %%
a < 8 or b < 5

# %%
a >8 and b > 5

# %%
a>8 or b>5

# %%
x1 = False
x1

# %%
y1 = not x1
y1

# %% [markdown]
# # print()

# %%
print(10) 
print(10,20)
print('python') 
print(10,20,'python') 
print(2, 2.3, 'nit', True, 1+2j)

# %%
num1=20 num2=30
add=num1+num2 print(add)

# %%
num1, num2 = 20, 30
add = num1 + num2  
print(add)

# %% [markdown]
# # print result with string

# %%
num1=20 
num2=30 
add=num1+num2

print('The addition of',num1,'and',num2,'is=',add)

# %%
num1=20 
num2=30
add=num1+num2

print('The addition of {} and {} is= {}'.format(num1,num2,add))

# %%
num1=20 
num2=30
num3=50

add=num1+num2+num3

print('The addition of {} and {} and {} is= {}'.format(num1,num2,num3, add))

# %%
num1 = 20
num2 = 30

add=num1+num2
print(f'The addition of {num1} and {num2} is= {add}')

# %% [markdown]
# # 10th

# %%
hi

# %%
#hi

# %%
'hi'

# %%
s1 = 'hello'
s1

# %%
a = 3
b = 'hi'

c = a + b
print(c)

# %%
'nit' + 'nit'

# %%
'nit' + ' nit'

# %%
'nit' * 'nit'

# %%
5 * 'nit'

# %%
5 * ' nit'

# %%
print('C:\nit') # \n - print new line

# %%
print(r'C:\nit')

# %%
tax = 20 
price = 15

price * tax

# %%
price + _ #_ it store previous value

# %%
round(15.2)

# %%
round(15.8)

# %%
help()

# %%
'doesnt'

# %%
'doesn\'t'

# %%
"doesn't"

# %%
index = 'welcome'
index
# Out:
# 'welcome'

# %%
index[0]
# Out:
# 'w'

# %%
print(index[0])
print(index[1])
print(index[2])
print(index[3])
print(index[4])
print(index[5])
print(index[6])
# Out:
# w
# e
# l
# c
# o
# m
# e

# %%
index
# Out:
# 'welcome'

# %%
for i in index:
    print(i)
# Out:
# w
# e
# l
# c
# o
# m
# e

# %%
index
# Out:
# 'welcome'

# %%
index[-10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 index[-10]
#
# IndexError: string index out of range

# %%
index
# Out:
# 'welcome'

# %%
index[5]
# Out:
# 'm'

# %%
index
# Out:
# 'welcome'

# %%
len(index)
# Out:
# 7

# %%
index[8]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 index[8]
#
# IndexError: string index out of range

# %%
index
# Out:
# 'welcome'

# %%
index[:]
# Out:
# 'welcome'

# %%
index[1:5]
# Out:
# 'elco'

# %%
index
# Out:
# 'welcome'

# %%
index[0:5]
# Out:
# 'welco'

# %%
index
# Out:
# 'welcome'

# %%
index[:5]
# Out:
# 'welco'

# %%
index[5:]
# Out:
# 'me'

# %%
index[:]
# Out:
# 'welcome'

# %%
index
# Out:
# 'welcome'

# %%
index[4:10]
# Out:
# 'ome'

# %%
index
# Out:
# 'welcome'

# %%
index[:10]
# Out:
# 'welcome'

# %%
index[10:]
# Out:
# ''

# %%
index
# Out:
# 'welcome'

# %%
index[10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 index[10]
#
# IndexError: string index out of range

# %%
s3 = 'hellopython'

# %%
index
# Out:
# 'welcome'

# %%
index[:10]
# Out:
# 'welcome'

# %%
index
# Out:
# 'welcome'

# %%
len(index)
# Out:
# 7

# %%
index[7]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 index[7]
#
# IndexError: string index out of range

# %%
index[7:]
# Out:
# ''

# %%
index[:7]
# Out:
# 'welcome'

# %%
index
# Out:
# 'welcome'

# %%
index[-8]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 index[-8]
#
# IndexError: string index out of range

# %%
i5 = 'nareshit'
i5
# Out:
# 'nareshit'

# %%
i5
# Out:
# 'nareshit'

# %%
i5[0:7:3]
# Out:
# 'nei'

# %%
i5
# Out:
# 'nareshit'

# %%
i5[2:-1]
# Out:
# 'reshi'

# %%
i5[::1]
# Out:
# 'nareshit'

# %%
i5[::2]
# Out:
# 'nrsi'

# %%
i5
# Out:
# 'nareshit'

# %%
i5[::3]
# Out:
# 'nei'

# %%
i5
# Out:
# 'nareshit'

# %%
i5[::-1]
# Out:
# 'tihseran'

# %%
i5[::-2]
# Out:
# 'thea'

# %%
i5
# Out:
# 'nareshit'

# %%
i5[::-3]
# Out:
# 'tsa'

# %%
index
# Out:
# 'welcome'

# %%
index[-6:2]
# Out:
# 'e'

# %% [markdown]
# # string we are complete

# %% [markdown]
# # Python Data Structure

# %%
l = []  
l
# Out:
# []

# %%
type(l)
# Out:
# list

# %%
len(l)
# Out:
# 0

# %%
l1 = [10, 20, 30, 40]
l1
# Out:
# [10, 20, 30, 40]

# %%
len(l1)
# Out:
# 4

# %%
type(l1)
# Out:
# list

# %%
print(l)
print(l1)
# Out:
# []
# [10, 20, 30, 40]

# %%
l == l1
# Out:
# False

# %%
l != l1
# Out:
# True

# %%
l1
# Out:
# [10, 20, 30, 40]

# %%
l
# Out:
# []

# %%
l.append(100) 
l.append(12.5)
l.append(True)
l.append(1+2j)
l.append([1,2,3])

# %%
l
# Out:
# [100, 12.5, True, (1+2j), [1, 2, 3]]

# %%
100 in l
# Out:
# True

# %%
1000 in l
# Out:
# False

# %%
l.append(100)

# %%
l
# Out:
# [100, 12.5, True, (1+2j), [1, 2, 3], 100]

# %%
print(l)
print(l1)
# Out:
# [100, 12.5, True, (1+2j), [1, 2, 3], 100]
# [10, 20, 30, 40]

# %%
print(len(l))
print(len(l1))
# Out:
# 6
# 4

# %%
l
# Out:
# [100, 12.5, True, (1+2j), [1, 2, 3], 100]

# %%
l.append(30, 40)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 l.append(30, 40)
#
# TypeError: list.append() takes exactly one argument (2 given)

# %%
l
# Out:
# [100, 12.5, True, (1+2j), [1, 2, 3], 100]

# %%
l.count(100)
# Out:
# 2

# %%
l.count(12.5)
# Out:
# 1

# %%
l.count(1000)
# Out:
# 0

# %%
l2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 l2
#
# NameError: name 'l2' is not defined

# %%
l1
# Out:
# [10, 20, 30, 40]

# %%
l2 = l1.copy()

# %%
l2
# Out:
# [10, 20, 30, 40]

# %%
print(l)
print(l1)
print(l2)
# Out:
# [100, 12.5, True, (1+2j), [1, 2, 3], 100]
# [10, 20, 30, 40]
# [10, 20, 30, 40]

# %%
l1.append(50)

# %%
l1
# Out:
# [10, 20, 30, 40, 50]

# %%
l2
# Out:
# [10, 20, 30, 40]

# %%
l2.append(50)

# %%
l2
# Out:
# [10, 20, 30, 40, 50]

# %%
l2.clear()

# %%
print(l)
print(l1)
print(l2)
# Out:
# [100, 12.5, True, (1+2j), [1, 2, 3], 100]
# [10, 20, 30, 40, 50]
# []

# %%
l2
# Out:
# []

# %%
l1
# Out:
# [10, 20, 30, 40, 50]

# %%
l2 = l1.copy()

# %%
l2
# Out:
# [10, 20, 30, 40, 50]

# %%
print(l)
print(l1)
print(l2)
# Out:
# [100, 12.5, True, (1+2j), [1, 2, 3], 100]
# [10, 20, 30, 40, 50]
# [10, 20, 30, 40, 50]

# %%
print(len(l))
print(len(l1))
print(len(l2))
# Out:
# 6
# 5
# 5

# %%
l
# Out:
# [100, 12.5, True, (1+2j), [1, 2, 3], 100]

# %%
l.extend(l1)

# %%
l
# Out:
# [100, 12.5, True, (1+2j), [1, 2, 3], 100, 10, 20, 30, 40, 50]

# %%
l1
# Out:
# [10, 20, 30, 40, 50]

# %%
l
# Out:
# [100, 12.5, True, (1+2j), [1, 2, 3], 100, 10, 20, 30, 40, 50]

# %%
l.index(10)
# Out:
# 6

# %%
l.index(100)
# Out:
# 0

# %%
l
# Out:
# [100, 12.5, True, (1+2j), [1, 2, 3], 100, 10, 20, 30, 40, 50]

# %%
l1
# Out:
# [10, 20, 30, 40, 50]

# %%
l1.insert(1, 15)

# %%
l1
# Out:
# [10, 15, 20, 30, 40, 50, 1]

# %%
l1
# Out:
# [10, 15, 20, 30, 40, 50, 1]

# %%
l1.insert(3, 25)

# %%
l1
# Out:
# [10, 15, 20, 25, 30, 40, 50, 1]

# %%
l1
# Out:
# [10, 15, 20, 25, 30, 40, 50, 1]

# %%
l
# Out:
# [100, 12.5, True, (1+2j), [1, 2, 3], 100, 10, 20, 30, 40, 50]

# %%
l.pop()
# Out:
# 50

# %%
l
# Out:
# [100, 12.5, True, (1+2j), [1, 2, 3], 100, 10, 20, 30, 40]

# %%
l.pop()
# Out:
# 40

# %%
l
# Out:
# [100, 12.5, True, (1+2j), [1, 2, 3], 100, 10, 20, 30]

# %%
l.pop()
# Out:
# 30

# %%
l
# Out:
# [100, 12.5, True, (1+2j), [1, 2, 3], 100, 10, 20]

# %%
l.pop(4)
# Out:
# [1, 2, 3]

# %%
l
# Out:
# [100, 12.5, True, (1+2j), 100, 10, 20]

# %%
l.pop(3)
# Out:
# (1+2j)

# %%
l
# Out:
# [100, 12.5, True, 100, 10, 20]

# %%
l.remove(True)

# %%
l
# Out:
# [100, 12.5, 100, 10, 20]

# %% [markdown]
# # List
# 1) List is an ordered sequence of items.
# 2) We can have different data types under a list. E.g. We can have integer, float, and string items in a same list.
#
#
#
# 1. List is defined using [] (square brackets)
# 2. Lis t is growable
# 3. append() will allow user to add the element or value at the end of the list.
# 4. You can declare multiple datatype inside the list.
# 5. List allows duplicates and it will append it to the end of the list.
# 6. append takes only one argument
# 7. Index() return the index value
# 8. insert() insert the value before index . insert always we need to pass 2 arguemnt
# 9. extend()- extend from one list to another list
# 10. copy list.
# 11. pop() by default it will remove  & print the last element value
#     pop(3) it will remove only 3rd index position value
#     pop() is index wise elimination
# 12. remove() not index
#
# # List creation

# %%
list1 = [] # Empty list 
print(type(list1))
# Out:
# <class 'list'>

# %%
list2 = [10,30,60] # list of integers numbers

list3 = [10.77, 30.66, 60.89] # List of float numbers

list4 = ['one', 'two', 'three'] # List of strings

list5 = ['Asif', 25,[50,100], [150,90]] #Nested Lists

list6 = [100, 'Asif', 17.765] # List of mixed data types 

list7 = ['Asif', 25, [50,100],[150,90],{'John','David'}]
len(list6) # Length of list
# Out:
# 3

# %% [markdown]
# # List Indexing
# 1. Forward indexing of list starts from 0 to n-1
#
# 2. Backward indexing of list starts from -1 to -n

# %%
list2[0] # Retrieve first element of the list
# Out:
# 10

# %%
list4[0] # Retrieve first element of the list
# Out:
# 'one'

# %%
list4[0][0] # Nested indexing - Access the first character of the first list element
# Out:
# 'o'

# %%
list4[-1] # Last item of the list
# Out:
# 'three'

# %%
list5[-1] # Last item of the list
# Out:
# [150, 90]

# %% [markdown]
# # List Slicing

# %%
mylist = ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']
mylist[0:3] # Return all items from 0th to 3rd index Location
# Out:
# ['one', 'two', 'three']

# %%
mylist[2:5] # List all items from 2nd to 5th index location
# Out:
# ['three', 'four', 'five']

# %%
mylist[:3] # Return first three items
# Out:
# ['one', 'two', 'three']

# %%
mylist[:2] # Return first two items
# Out:
# ['one', 'two']

# %%
mylist[-3:] # Return last three items
# Out:
# ['six', 'seven', 'eight']

# %%
mylist[-2:] # Return last two items
# Out:
# ['seven', 'eight']

# %%
mylist[-1] # Return last item of the list
# Out:
# 'eight'

# %%
mylist[:] # Return whole list
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %% [markdown]
# # Add, Remove & Change Items

# %%
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
mylist.append('nine') # Add an item to the end of the list 
mylist
# Out:
# ['one',
#  'two',
#  'three',
#  'four',
#  'five',
#  'six',
#  'seven',
#  'eight',
#  'nine',
#  'nine',
#  'nine']

# %%
mylist.insert(9,'ten') # add item at index Location 9 
mylist
# Out:
# ['one',
#  'two',
#  'three',
#  'four',
#  'five',
#  'six',
#  'seven',
#  'eight',
#  'nine',
#  'ten',
#  'nine',
#  'nine']

# %%
mylist.insert(1,'one') # Add iteam at index location 1 
mylist
# Out:
# ['one',
#  'one',
#  'two',
#  'three',
#  'four',
#  'five',
#  'six',
#  'seven',
#  'eight',
#  'nine',
#  'ten',
#  'nine',
#  'nine']

# %%
mylist.remove('one') # Remove item "one"
mylist
# Out:
# ['one',
#  'two',
#  'three',
#  'four',
#  'five',
#  'six',
#  'seven',
#  'eight',
#  'nine',
#  'ten',
#  'nine',
#  'nine']

# %%
mylist.pop() # Remove last item of the list 
mylist
# Out:
# ['one',
#  'two',
#  'three',
#  'four',
#  'five',
#  'six',
#  'seven',
#  'eight',
#  'nine',
#  'ten',
#  'nine']

# %%
mylist.pop(8) # Remove item at index location 8 
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'ten', 'nine']

# %%
del mylist[7] #Remove item at index location 7 
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'ten', 'nine']

# %%
# Change value of the string 
mylist[0] = 1 
mylist[1] = 2
mylist[2] = 3
mylist
# Out:
# [1, 2, 3, 'four', 'five', 'six', 'seven', 'ten', 'nine']

# %%
mylist.clear() # Empty List/ Delete all items in the list 
mylist
# Out:
# []

# %%
del mylist # Delete the whole list 
mylist
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 2
#       1 del mylist # Delete the whole list
# ----> 2 mylist
#
# NameError: name 'mylist' is not defined

# %% [markdown]
# # Copy List

# %%
mylist = ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']
mylist1 = mylist # Create a new reference "mylist1"
id(mylist), id(mylist1) # THe address of both mylist & mylist1 will be the same
# Out:
# (4718866240, 4718866240)

# %%
mylist2 = mylist.copy() # Create a copy of the list

# %%
id(mylist2) # The address of mylist 2 will be different from mylist because my list2 is a copy of mylist1
# Out:
# 4718855552

# %%
mylist[0] = 1 
mylist
# Out:
# [1, 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
mylist1 # mylist1 will also be impacted as it is pointing to the same list
# Out:
# [1, 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
mylist2 # copy of list wont be impacted due to the changes made on the original list
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %% [markdown]
# # Join Lists

# %%
list1 = ['one', 'two', 'three', 'four']
list2 = ['five', 'six', 'seven', 'eight']
list3 = list1 + list2 # Join two lists by '+' operator 
list3
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
list1.extend(list2) # Append list2 with list1 
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %% [markdown]
# # List Membership

# %%
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
'one' in list1 # Check if 'one' exist in the list
# Out:
# True

# %%
'ten' in list1 # check if 'ten' exist in the list
# Out:
# False

# %%
if 'three' in list1 : # Check if 'three' exist in the list 
    print('Three is present in the list')
else: 
    print('three is not present in the list ')
# Out:
# Three is present in the list

# %%
if 'eleven' in list1 : # Check if 'eleven' exist in the list 
    print('eleven is present in the list')
else: 
    print('eleven is not present in the list')
# Out:
# eleven is not present in the list

# %% [markdown]
# # Reverse & Sort List

# %%
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
list1.reverse() # Reverse the list 
list1
# Out:
# ['eight', 'seven', 'six', 'five', 'four', 'three', 'two', 'one']

# %%
list1 = list1[::-1] # Reverse the list

# %%
print(list1)
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
mylist3 = [9,5,2,99,12,88,34]
mylist3.sort() # Sort list in ascending order 
mylist3
# Out:
# [2, 5, 9, 12, 34, 88, 99]

# %%
mylist3 = [9,5,2,99,12,88,34]
mylist3.sort(reverse=True) # Sort list in descending order 
mylist3
# Out:
# [99, 88, 34, 12, 9, 5, 2]

# %%
mylist4 = [88,65,33,21,11,98]
sorted(mylist4) # Returns a new sorted list and doesn't change original
# Out:
# [11, 21, 33, 65, 88, 98]

# %%
mylist4
# Out:
# [88, 65, 33, 21, 11, 98]

# %% [markdown]
# # Loop through a list

# %%
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
for i in list1: 
    print(i)
# Out:
# one
# two
# three
# four
# five
# six
# seven
# eight

# %%
for i in enumerate(list1):
    print(i)
# Out:
# (0, 'one')
# (1, 'two')
# (2, 'three')
# (3, 'four')
# (4, 'five')
# (5, 'six')
# (6, 'seven')
# (7, 'eight')

# %% [markdown]
# # Count

# %%
list10 = ['one', 'two', 'three', 'four', 'one', 'one', 'two', 'three']
list10.count('one') # Number of times "one" occured in the list
# Out:
# 3

# %%
list10.count('two') # Occurence of item 'two' in the list
# Out:
# 2

# %%
list10.count('four') # Occurence of item 'four' in the list
# Out:
# 1

# %% [markdown]
# # All()/ Any methods/functions
# The all() method returns:
# 1. True - if all elements in a list are true
# 2. False - if any element ia list is false
# The any() function returns True if any element in the list is True. if not, any() returns False.

# %%
L1 = [1,2,3,4,0]
all(L1) # Will Return false as one value is false(Value 0)
# Out:
# False

# %%
any(L1) # Will Return True as we have items in the list with True value
# Out:
# True

# %%
L2 = [1,2,3,4,True,False]
all(L2) #Returns false as one value is false
# Out:
# False

# %%
any(L2) # Will Return True as we have items in the list with True value
# Out:
# True

# %%
L3 = [1,2,3,True]
all(L3) # Will return True as all items in the list are True
# Out:
# True

# %%
Print(L1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 Print(L1)
#
# NameError: name 'Print' is not defined

# %%
l = [100,12.5,100,10,20]
l.reverse();
print(l);
# Out:
# [20, 10, 100, 12.5, 100]

# %%
l.sort()
l
# Out:
# [10, 12.5, 20, 100, 100]

# %%
l3 = ['a', 2.3, 1+2j, True ] # Sort functions only when we pass similar datatypes 
l3.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 2
#       1 l3 = ['a', 2.3, 1+2j, True ]
# ----> 2 l3.sort()
#
# TypeError: '<' not supported between instances of 'float' and 'str'

# %%
l1  = [ 10,15, 20, 25, 20,15,10,1]
l1.sort(reverse=True)
l1
# Out:
# [25, 20, 20, 15, 15, 10, 10, 1]

# %% [markdown]
# # Parameter Tunning -- System given default parameter
# # hyperparameter Tuning -- User change the System Parameter

# %%
l = [2,8,3]
l.sort() # Parameter Tunning 
print(l)
# Out:
# [2, 3, 8]

# %%
l.sort(reverse=True) #Hyperparameter Tuning
print(l)
# Out:
# [8, 3, 2]

# %%
for i in l: # For loop i is iteration 
    # system automating generates space it is called indentatiton makes it easy for reading. 
    print(i)
# Out:
# 8
# 3
# 2

# %%
for i in enumerate (l): # enumerate means Retun enumerate object,The enumerate object yields pairs containing a count (from start, which
                        # defaults to zero) and a value yielded by the iterable argument. 
    print (i)
# Out:
# (0, 8)
# (1, 3)
# (2, 2)
