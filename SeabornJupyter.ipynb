# %% [markdown]
# # **SEABORN**
#
# **Seaborn** is a Python visualization library built on top of Matplotlib that provides high-level functions to create statistical and attractive graphs using Pandas data.

# %%
# !pip install --upgrade matplotlib seaborn # installing seaborn in python environment
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.11.2
#     Uninstalling seaborn-0.11.2:
#       Successfully uninstalled seaborn-0.11.2
# ...

# %%
pip install matplotlib==3.8.4 seaborn==0.13.2
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 5.4 MB/s  0:00:01 eta 0:00:01m
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [seaborn]m1/2 [seaborn]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
 # properly working version with no issues. 
import seaborn as sns  # seaborn and matplotlib inserted 
print(plt.__version__)
print(sns.__version__)
# Out:
# 3.8.4
# 0.13.2

# %%
sns.get_dataset_names()# these are sample dataset which are avaialble in seaborn and can be loaded. 
# We can use these datasets for practising.
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 

#Load sample dataset 
tips = sns.load_dataset("tips")

#Set a visual theme 
sns.set_theme(style = "darkgrid")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# save to CSV 
tips.to_csv("tips_dataset.csv", index = False)

# %%
import os 
os.getcwd() # Current working directory.
# Out:
# '/Users/venkatasaikumargundu/Desktop/FullStack python Datascience and AI/PythonBasics'

# %%
plt.figure(figsize = (8,6)) # figure() creates a new empty figure and sets 8 width and 6 height of the plot in inches
# We Use figsize to control layout for reports or Jupyter notebooks 
# Make charts readable 
# Avoid tiny or stretched plots. 
# Bigger width -> good for time series. 
# Bigger Height -> good for bar charts with many labels.

# %%
# 1. Scatter Plot: Total Bill vs Tip, with hue and size. 
#scatterplot() is a type of graph used to show the relationship between two numerical variables 
# by displaying data as individual points on an x-y coordinate plane. 
sns.scatterplot(data = tips, x="total_bill", y="tip", hue="time", size="size", palette="deep")
plt.title("Scatter Plot : Total Bill vs Tip by Time and Size")
plt.show()
'''
data = tips , uses the tips data set 
x = "total_bill"( x-axis shows total bill amount)
y = "tip"(y-axis shows tip value)
hue ="time"(Colors points by lunch vs Dinner)
Size = "size"(marker size depends on number of people at the table)
paletter ="deep" Professional color theme 
You’re visualizing 4 variables in one chart:
	•	Relationship: bigger bill → usually bigger tip
	•	Color separation: lunch vs dinner patterns
	•	Circle size: larger parties vs small tables
'''

# %%
#2 Line Plot : Total Bill by Party Size,split by Sex 
sns.lineplot(data=tips, x="size", y="total_bill", hue="sex", ci=None, marker="o")
plt.title("Line Plot: Total Bill by Party Size and Sex")
plt.show()
'''
data = tips , uses the tips data set 
x = "size"( x-axis shows party size )
y = "tip"(y-axis shows total bill amount)
hue ="sex"(creates separate lines for Male and Female)
ci  = NONE(Removes confidence interval shading , By default seaborn shows a shaded band.)
marker ="o" Adds circle markers at each data point.
'''

# %%
# 3. Bar Plot: Average Total Bill by Day, split by Sex

sns.barplot(data=tips, x="day", y="total_bill", hue="sex", palette="muted")
plt.title("Bar Plot: Average Total Bill by Day and Sex")
plt.show()
'''
x ='day'
y = 'total_bill'
hue = 'sex'
palette = 'muted' soft professional-looking colors. 

'''

# %%
# 4. Box Plot: Total Bill by Day, split by Time

sns.boxplot(data=tips, x="day", y="tip", hue="smoker", palette="Set2")
plt.title("Box Plot: Tips by Day and Smoker Status")
plt.show()
'''
x = 'Day'
y = 'tip'
hue ='smoker' (smoker and non smoker split )
paletter = 'set2' soft pastel color theme from seaborn.
middle line -> Median tip
Box edges -> 25th & 75th Percentiles 
Whiskers -> data range 
Dots Outsie -> Outliers 
'''

# %%
#5. Violin Plot: Total Bill by Day, split by Time
sns.violinplot(data=tips, x="day", y="total_bill", hue="time", split=True, palette="pastel")
plt.title("Violin Plot: Total Bill by Day and Time")
plt.show()

'''
data = tips ( uses the seaborn tips dataset. 
x='day' creates one violin for each day ( thur, friday sat, sun )
y = 'total_bill' shows distribution of bill amounts 
hue = 'time' splits the data by Lunch vs Dinner. 
split= True Combines the two hue categoies into one violin per day. 
        left side = One category , right side = another. 

palette = 'pastel' 

'''

# %%
# 6. count plot : order by Day , Split by smoker 

sns.countplot(data=tips, x="day", hue="smoker", palette="dark")
plt.title("Count Plot: Orders by Day and Smoker Status")
plt.show()

'''
data = tips 
x = 'day' 
hue = smoker vs non-smoker 
palette = dark 
'''

# %%
# 7. Regression Plot: Total Bill vs Tip with regression line

sns.regplot(data=tips, x="total_bill", y="tip", scatter_kws={"s": 50}, line_kws={"color": "red"})
plt.title("Regression Plot: Total Bill vs Tip")
plt.show()
'''
x = ' total bill amount'
y = 'tip amount'
scatter _kws = {"s":50} Controls scatter point size 
s = marker size. 
line_kws ={"color": "red"}

regplot for visual correlation. = GROUP BY + trend analysis
'''

# %%
# 8. Histogram ( Distribution Plot ): total Bill with KDE 
sns.histplot(data = tips, x = "total_bill", kde = True, bins = 20, color = "blue")
plt.title ("Histogram: Distribution of Total Bill")
plt.show()
'''
data = 'tips'
x = 'total_bill'
bins = 20 splits data into 20 intervals 
kde = true adds kernel density estimation curve 
color = blue sets bar color 
'''

# %%
#9 Pair Plot: relationships between numerical variables

sns.pairplot(tips, hue="sex", vars=["total_bill", "tip", "size"], palette="husl")
plt.suptitle("Pair Plot: Numerical Variables by Sex", y=1.02)
plt.show()

'''
vars = ["total_bill", "tip", "size"]
You are selecting only these numeric columns to compare: total_bill, tip ,size
hue = "sex" Colors the data points by Male vs Female 
Palette = "husl" Applies a bright , evenly spaced color palette

'''
# Out:
# '\nvars = ["total_bill", "tip", "size"]\nYou are selecting only these numeric columns to compare: total_bill, tip ,size\nhue = "sex" Colors the data points by Male vs Female \nPalette = "husl" Applies a bright , evenly spaced color palette\n\n'

# %%
#10. Catplot (point plot): Tip by day and sex 
sns.catplot(data=tips, x="day", y="tip", hue="sex", kind="point", palette="bright")
plt.title("Catplot (Point): Tips by Day and Sex")
plt.show()

'''  
Kind = "point"  shows means values of tip for each category. 
vertical lines = confidence intervals(by default 95%)
x = "day"
y = "tip"
hue = "sex"
palette = "bright"
histplot() → distribution
regplot() → relationship
pairplot() → multiple relationships
catplot(kind="point") → GROUP BY + AVG visualization
'''

# %%
# 11. Joint Plot: Total Bill Vs Tip with marginal distributions 
sns.jointplot(data=tips, x="total_bill", y="tip", kind="scatter", hue="smoker", palette="coolwarm")
plt.suptitle("Joint Plot: Total Bill vs Tip by Smoker", y=1.02)
plt.show()
'''
x= "total_bill", y = "tip"
kind = "scatter"
hue ="smoker or non-smoker"
palette  = "cool warm"
'''
# Out:
# '\nx= "total_bill", y = "tip"\nkind = "scatter"\nhue ="smoker or non-smoker"\npalette  = "cool warm"\n'

# %%
#12. FacetGrid: Total Bill by Day, faceted by Time and Smoker 
g = sns.FacetGrid(tips, col = "time", row = "smoker", margin_titles = True)
g.map(sns.histplot, "total_bill", bins = 15)
g.fig.suptitle("FacetGrid: Total Bill by Time and Smoker", y=1.02)
plt.show()

# %%
# 13. Strip Plot: Tips by Day, colored by Sex
plt.figure(figsize=(8, 6))
sns.stripplot(data=tips, x="day", y="tip", hue="sex", palette="Set1", jitter=True)
plt.title("Strip Plot: Tips by Day and Sex")
plt.show()

# %%
# 14. KDE Plot: Total Bill density by Sex
plt.figure(figsize=(8, 6))
sns.kdeplot(data=tips, x="total_bill", hue="sex", fill=True, palette="tab10")
plt.title("KDE Plot: Total Bill Density by Sex")
plt.show()

# %% [markdown]
# # **Explanation of Plots:**
#
# - Scatter Plot: Shows the relationship between total_bill and tip, with time and size as additional dimensions.
# - Line Plot: Trends of total_bill across size, split by sex.
# - Bar Plot: Average total_bill by day, split by sex.
# - Box Plot: Distribution of tip by day, split by smoker.
# - Violin Plot: Distribution of total_bill by day, split by time.
# - Count Plot: Counts of orders by day, split by smoker.
# - Regression Plot: Linear fit between total_bill and tip.
# - Histogram: Distribution of total_bill with a KDE curve.
# - Pair Plot: Pairwise relationships between total_bill, tip, and size, colored by sex.
# - Catplot (Point): Point estimates of tip by day and sex.
# - Joint Plot: total_bill vs tip with marginal histograms, colored by smoker.
# - FacetGrid: total_bill histograms faceted by time and smoker.
# - Strip Plot: Individual tip points by day, colored by sex.
# - KDE Plot: Density of total_bill split by sex.
