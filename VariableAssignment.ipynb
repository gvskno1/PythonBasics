# %%
#Variable Assignment 
intvar = 10 # 
floatvar =2.57 # Float Variable 
starvar = "Python Language" # String Variable 
print(intvar)
print(floatvar)
print(starvar)
# Out:
# 10
# 2.57
# Python Language

# %%
#Multiple Assignments 
intvar, floatvar, strvar = 10, 2.57, "Python Language" #Using commas to separate 
print(intvar)
print(floatvar)
print(strvar)
# Out:
# 10
# 2.57
# Python Language

# %%
p1 = p2 = p3 = p4 = 44 # All variables pointing to same value 
print(p1,p2,p3,p4)
# Out:
# 44 44 44 44

# %% [markdown]
# ==============DATA TYPES==================

# %%
#Numeric
import sys 
val1 = 10 # Integer data type 
print(val1)
print(type(val1))# type of object
print(sys.getsizeof(val1))
print(val1, "is Integer?", isinstance(val1, int)) #val1 is an instance of int
# Out:
# 10
# <class 'int'>
# 28
# 10 is Integer? True

# %%
val2 = 92.78 # Float data type 
print(val2)
print(type(val2))# type of object
print(sys.getsizeof(val2))
print(val2, "is float?", isinstance(val2, float)) #val2 is an instance of float
# Out:
# 92.78
# <class 'float'>
# 24
# 92.78 is float? True

# %%
val3 = 25+10j #complex data type 
print(val3)
print(type(val3))# type of object
print(sys.getsizeof(val3))
print(val3, "is complex?", isinstance(val3, complex)) #val3 is an instance of complex
# Out:
# (25+10j)
# <class 'complex'>
# 32
# (25+10j) is complex? True

# %%
sys.getsizeof(int())#size of integer object in bytes
# Out:
# 28

# %%
sys.getsizeof(float())#size of integer object in bytes
# Out:
# 24

# %%
sys.getsizeof(complex()) # size of complex object in bytes
# Out:
# 32

# %%
#Boolean - Boolean data type can have only two possible values True or False with capital T and F only 

bool1 = True
bool2 = False
print(type(bool1))
print(type(bool2))
# Out:
# <class 'bool'>
# <class 'bool'>

# %%
isinstance(bool1, bool)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(1)
# Out:
# True

# %%
bool(None)
# Out:
# False

# %%
bool (False)
# Out:
# False

# %% [markdown]
# =================STRINGS===================

# %%
#String Creation 
str1 = "HELLO PYTHON"
print(str1)
# Out:
# HELLO PYTHON

# %%
mystr = 'Hello World' #Define string using single quotes
print(mystr)
# Out:
# Hello World

# %%
mystr = "Hello World" #Define string using double quotes
print(mystr)
# Out:
# Hello World

# %%
mystr = '''Hello
                world''' #Define string using triple quotes
print(mystr)
# Out:
# Hello
#                 world

# %%
mystr = """Hello
                World""" #Define string using triple quotes
print(mystr)
# Out:
# Hello
#                 World

# %%
mystr = ('Happy'
         'Monday'
         'Everyone')
print(mystr)
# Out:
# HappyMondayEveryone

# %%
mystr2 = 'Woohoo '
mystr2 = mystr2*5
mystr2
# Out:
# 'Woohoo Woohoo Woohoo Woohoo Woohoo '

# %%
len(mystr2) #Length of string
# Out:
# 35

# %% [markdown]
# # String Indexing
# # Forward indexing in python starts from 0 to n-1
# # Backward indexing in python starts from -1 to -n

# %%
str1
# Out:
# 'HELLO PYTHON'

# %%
str1[0] # First character in string "str1"
# Out:
# 'H'

# %%
str1[len(str1)-1] #last character in string using len function
# Out:
# 'N'

# %%
str1[-1] #Last character in string
# Out:
# 'N'

# %%
str1[6] #Fetch 7th element of the string
# Out:
# 'P'

# %%
str1[5]
# Out:
# ' '

# %% [markdown]
# # String Slicing

# %%
str1[0:5] #String slicing - Fetch all characters from 0 to 5 index location exc
# Out:
# 'HELLO'

# %%
str1[6:12] #String slicing - Retrieve all characters between 6 - 12 index loce
# Out:
# 'PYTHON'

# %%
str1[-4:] #Retrieve last four characters of the string
# Out:
# 'THON'

# %%
str1[-6:] # Retrieve last six characters of the string
# Out:
# 'PYTHON'

# %%
str1[:4] # Retrieve first four characters of the string
# Out:
# 'HELL'

# %%
str1[:6] # Retrieve first six characters of the string
# Out:
# 'HELLO '

# %% [markdown]
# # Update & Delete String

# %%
str1
# Out:
# 'HELLO PYTHON'

# %%
# Strings are immutable which means elements of a string cannot be changed once
str1[0:5] = 'HOLAA'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[52], line 2
#       1 #S trings are immutable which means elements of a string cannot be changed once
# ----> 2 str1[0:5] = 'HOLAA'
#
# TypeError: 'str' object does not support item assignment

# %%
del str1 #Delete a string 
print(str1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 2
#       1 del str1 #Delete a string
# ----> 2 print(str1)
#
# NameError: name 'str1' is not defined

# %% [markdown]
# # String concentation

# %%
# String concatenation

# %%
s1 = "Hello"
s2 = "Asif"
s3 = s1 + s2
print(s3)
# Out:
# HelloAsif

# %% [markdown]
# # PRINT STATEMENTS

# %%
# Print is used for answer 
a = 10
b = 20
a
b
# Out:
# 20

# %%
a = 10
b = 20
print (a)
print (b)
# Out:
# 10
# 20

# %%
print(10)
print(10,20)
print('python')
print(10,20,'python')
# Out:
# 10
# 10 20
# python
# 10 20 python

# %%
num1 = 20
num2 = 30 
add = num1 + num2 
print(add)
# Out:
# 50

# %% [markdown]
# # Print result with String

# %%
num1 = 20
num2 = 30 
add = num1 + num2
print('The addition of ', num1, 'and', num2, 'is =', add)
# Out:
# The addition of  20 and 30 is = 50

# %%
name = 'Python'
age = 20
city = 'hyd'
# hellow my name is python and i am 10 year old from hyderabad

# %%
print('My name is ',name, 'and i am', age, 'years old from', city)
# Out:
# My name is  Python and i am 20 years old from hyd

# %% [markdown]
# Print Format Method

# %%
num1 = 20 
num2 = 30 
add = num1 + num2 
print(' The addition of {} and {} is = {}'.format(num1, num2,add))

# First decide how the print should be EX: The addition of 20 and 30 is = 50
# Then replace the variable position with curly brtaacesm{} 
# then apply.format(va1, val2,.....val-n) method
# Out:
#  The addition of 20 and 30 is = 50

# %%
name = 'Python'
age = 20
city = 'hyd '
#hello my name is python and I am 10 year old from hyderabad 

print('hello my name is {}, and i am {} years old from {}' . format(name,age,city))
# Out:
# hello my name is Python, and i am 20 years old from hyd

# %%
num1 = 100 
num2 = 25 
num3 = 333 
avg= (num1 + num2 + num3)/ 3 # or we can use avg = round(num1 + num2 + num3)/3,2)
avg1 = round((num1 + num2 + num3)/3,2)
# The average of num1, num2, num3 is = avg
print('The average of {}, {}, and {} is = {} or {}'.format(num1,num2,num3,avg,avg1))
#here we can use round(avg,2)also
# Out:
# The average of 100, 25, and 333 is = 152.66666666666666 or 152.67

# %%
round(avg,2) # round of till 2 digite after decimal
# Out:
# 152.67

# %% [markdown]
# More short format method (f string method)
# - variable should be in curly braces
# - and write everything inside quotes''
# - at starting simply add f

# %%
num1 = 20 
num2 = 30 
add = num1 + num2 
print(f'The additin of {num1} and {num2} is = {add}') # always prefer this
# Out:
# The additin of 20 and 30 is = 50

# %%
name = 'Python'
age = 20 
city = 'hyd'
#hello my name is python and I am 10 year old from hyderabad

# %%
print(f'hello my name is {name}. and i am {age} year old, from {city}.')
# Out:
# hello my name is Python. and i am 20 year old, from hyd.

# %%
num1 = 100 
num2 = 25 
num3 = 333 
avg = round((num1 + num2 + num3)/3,2) # or we can use avg = round(num1 + num2 + num3)/3,2)
# The average of num1, num2, num3, is = avg

# %%
print(f'The average of {num1},{num2} and {num3} is = {avg}')
# Out:
# The average of 100,25 and 333 is = 152.67

# %%
# lets Combine all 
num1 = 20 
num2 = 20 
add = num1 + num2 
print('The addition of',num1 ,'and', num2, 'is =',add)
print('The addition of {} and {} is = {}'.format(num1, num2, add))
print(f'The addition of {num1} and {num2} is = {add}')
# Out:
# The addition of 20 and 20 is = 40
# The addition of 20 and 20 is = 40
# The addition of 20 and 20 is = 40

# %% [markdown]
# END STATEMENT

# %%
print('hello') # 1st statement 
print('good morning') # 2nd statement 
# I want print like : - hello good morning
# Out:
# hello
# good morning

# %%
# Here we will use end statement that join line from end of one string to starting of other string
print('hello', end= ' ')# 1st statement 
print('world good day')#2nd statement
# Out:
# hello world good day

# %% [markdown]
# # Separator
# - here one print statement only we use
#
# - inside one print statement we have multiple values
#
# - we want to separate these multiple values with anything

# %%
print ('hello', 'hai', 'how are you', sep='---->')
# Out:
# hello---->hai---->how are you

# %%
print('hello ', ' hai ', ' how are you ', sep='&')
# Out:
# hello & hai & how are you

# %%
print('hello','hai','how are you',sep='@')
# Out:
# hello@hai@how are you

# %%
print('hello','hai','how are you',sep=
' ')
# Out:
# hello hai how are you

# %%
print(3,'.') # . is far from 3 so here we will use sep method
# Out:
# 3 .

# %%
print(3,'.',sep=
'') # see now space setteld(also use to remove space B/W words)
# Out:
# 3.

# %%
print(1,2,end=' ')
print(3,'.',sep=
'')
# will print 1 2 3.
# Out:
# 1 2 3.

# %% [markdown]
# # Using Escape Character

# %%
#Using double quotes in the string is not allowed.
mystr = "My favourite TV Series is "Game of Thrones""
# Out:
#   Cell In[106], line 2
#     mystr = "My favourite TV Series is "Game of Thrones""
#                                         ^
# SyntaxError: invalid syntax

# %%
#Using escape character to allow illegal characters
mystr = "My favourite series is \"Game of Thrones\""
print(mystr)
# Out:
# My favourite series is "Game of Thrones"
